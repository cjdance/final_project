# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
bout_sum_csv = "bout_summary.csv"
fighter_csv = "fighter_data.csv"

# %%
bout_df = pd.read_csv(bout_sum_csv)
bout_df.head()
# Out:
#            fight_id       fighter_1      fighter_1_id          fighter_2  \
# 0  d7cbe2f23d75afd1      Julio Arce  1291edf2d566a71a      Hakeem Dawodu
# 1  f0418c2c989a5cde  Grigorii Popov  d3fa5c5955397532        Davey Grant
# 2  fc16ccf0994c6e50      Jack Shore  b8a85389d115e35a  Nohelin Hernandez
# 3  18e1b0df8da7010e    Vanessa Melo  9b7dfb3b7d99926a       Tracy Cortez
# 4  57ff0eb2351979c4     Khalid Taha  b4537562f88ac582        Bruno Silva
#
#        fighter_2_id         winner       decision_method  \
# 0  2c9d00968f818270  Hakeem Dawodu      Decision - Split
# 1  113df4fde64735c6    Davey Grant      Decision - Split
# 2  f97c5433c77522d3     Jack Shore            Submission
# 3  68d4a891e5cf2029   Tracy Cortez  Decision - Unanimous
# 4  294aa73dbf37d281    Khalid Taha            Submission
#
#    fight_duration_lastrnd fight_duration_lastrnd_time    time_format  \
# 0                       3                        5:00  3 Rnd (5-5-5)
# ...

# %%
## List of transformations to be performed

# remove fighter id columns from the dataset
# drop any fights with an unlimited time limit
# drop location data, it will not be used in this project

bout_df = bout_df[["fight_id","fighter_1", "fighter_2", "winner", "decision_method", "fight_duration_lastrnd", "fight_duration_lastrnd_time",
                 "time_format", "weight_class", "date"]]

# %%
bout_df["time_format"].unique()
# Out:
# array(['3 Rnd (5-5-5)', 'No Time Limit', '5 Rnd (5-5-5-5-5)',
#        '1 Rnd (20)', '1 Rnd (15)', '1 Rnd + OT (12-3)', '1 Rnd (10)',
#        '1 Rnd + 2OT (15-3-3)', '1 Rnd + 2OT (24-3-3)',
#        '1 Rnd + OT (15-3)', '1 Rnd (18)', '1 Rnd + OT (27-3)',
#        '1 Rnd + OT (30-3)', '1 Rnd + OT (30-5)', '1 Rnd + OT (31-5)',
#        '1 Rnd (30)', '1 Rnd (12)', '2 Rnd (5-5)', '3 Rnd + OT (5-5-5-5)'],
#       dtype=object)

# %%
bout_df = bout_df.drop(bout_df.index[bout_df["time_format"] != '3 Rnd (5-5-5)'])
bout_df
# Out:
#               fight_id       fighter_1          fighter_2           winner  \
# 0     d7cbe2f23d75afd1      Julio Arce      Hakeem Dawodu    Hakeem Dawodu
# 1     f0418c2c989a5cde  Grigorii Popov        Davey Grant      Davey Grant
# 2     fc16ccf0994c6e50      Jack Shore  Nohelin Hernandez       Jack Shore
# 3     18e1b0df8da7010e    Vanessa Melo       Tracy Cortez     Tracy Cortez
# 4     57ff0eb2351979c4     Khalid Taha        Bruno Silva      Khalid Taha
# ...                ...             ...                ...              ...
# 5438  953c89aa931082e4   Jose Quinonez     Carlos Huachin    Jose Quinonez
# 5439  c163ed45c21c8548    Irene Aldana       Vanessa Melo     Irene Aldana
# 5440  49b2a6a93d529981    Martin Bravo    Steven Peterson  Steven Peterson
# 5441  fd3e8f61d8fda839  Brandon Moreno      Askar Askarov             Draw
# 5442  b2cdb4c34f37ad37   Carla Esparza       Alexa Grasso    Carla Esparza
#
#            decision_method  fight_duration_lastrnd  \
# ...

# %%
new = bout_df["fight_duration_lastrnd_time"].str.split(":")

# %%
bout_df["fight_max_length"] = dt.timedelta(minutes=5) * bout_df["fight_duration_lastrnd"]

# %%
bout_end_times = []

for i in new:
    end_time = dt.timedelta(minutes=int(i[0]), seconds=int(i[1]))
    bout_end_times.append(end_time)
    
bout_df["bout_end_time"] = bout_end_times

# %%
fight_length = []

for i in bout_df["bout_end_time"]:
    j = 0
    if i == dt.timedelta(minutes=5):
        bout_length = bout_df["fight_max_length"][j].total_seconds()/60
        j = j + 1
        
    else:
        bout_length = bout_df["fight_max_length"][j] - i
        bout_length = bout_length.total_seconds()/60
        j = j + 1
    
    fight_length.append(bout_length)
    
bout_df["fight_length_min"] = fight_length

# %%
bout_df = bout_df.drop("fight_max_length", axis = 1)
bout_df = bout_df.drop("bout_end_time", axis=1)

# %%
new = bout_df["date"].str.split(",")    
years = []

for i in new:
    year = i[1]
    years.append(year)
    
bout_df["date"] = years

# %%
bout_df = bout_df.drop(["fighter_1", "fighter_2"], axis = 1)
bout_df
# Out:
#               fight_id           winner       decision_method  \
# 0     d7cbe2f23d75afd1    Hakeem Dawodu      Decision - Split
# 1     f0418c2c989a5cde      Davey Grant      Decision - Split
# 2     fc16ccf0994c6e50       Jack Shore            Submission
# 3     18e1b0df8da7010e     Tracy Cortez  Decision - Unanimous
# 4     57ff0eb2351979c4      Khalid Taha            Submission
# ...                ...              ...                   ...
# 5438  953c89aa931082e4    Jose Quinonez  Decision - Unanimous
# 5439  c163ed45c21c8548     Irene Aldana  Decision - Unanimous
# 5440  49b2a6a93d529981  Steven Peterson                KO/TKO
# 5441  fd3e8f61d8fda839             Draw      Decision - Split
# 5442  b2cdb4c34f37ad37    Carla Esparza   Decision - Majority
#
#       fight_duration_lastrnd fight_duration_lastrnd_time    time_format  \
# 0                          3                        5:00  3 Rnd (5-5-5)
# 1                          3                        5:00  3 Rnd (5-5-5)
# ...

# %%
fighter_df = pd.read_csv(fighter_csv)
fighter_df
# Out:
#                dob        fighter_id  height  n_draw  n_loss  n_win  \
# 0     Mar 02, 1992  2af2f2e26c4c0402   5' 8"       0       0      8
# 1     Jul 27, 1986  f72465a784c1b084   5' 6"       0       7     14
# 2     Aug 11, 1990  55ed59d541f8b90c   5' 8"       1       7      9
# 3     Feb 07, 1989  44a94bbde42246e4   5' 9"       0       3      7
# 4     Dec 25, 1984  d024ed963e8bf7ea  5' 10"       0      12     17
# ...            ...               ...     ...     ...     ...    ...
# 3391  Jul 12, 1972  6014d25e73b669c9  5' 11"      10      27     40
# 3392  Jul 18, 1984  d06f8869449ba7bd   6' 3"       1       9     24
# 3393  Sep 12, 1984  94527830000ab715   5' 6"       0      10     26
# 3394  Mar 23, 1979  cc84b68f862b466f   5' 7"       1       5     16
# 3395  Nov 29, 1983  85248da6e9e2f7e7   6' 1"       0       2      5
#
#                     name reach  sig_str_abs_pM  sig_str_def_pct  \
# 0           Hunter Azure   69"            1.57             0.56
# ...

# %%
## List of transformations to be performed

# remove fighter_id column, we need to use the index as the fighter id when dropping into postgresSql
# convert DOB column into datetime format for ease of use in later calculations
# create a total fights column which adds draws/losses/wins for a total
# check for duplicate fighter names and drop the fighter with the lowest number of total fights (more fights means more data for their stats)
# drop any fighter with null values or zeroes in the sig_str_abs_PM and other columns, zeroes or nulls here would indicate they have no fight data
# add a weightclass column alongside fighter weight
# check for null values in stance column and replace with "Orthodox", fighters with no stance will be assumed for now (i.e. right handed)

# %%
fighter_df = fighter_df.drop("fighter_id", axis=1)

# %%
fighter_df["total_fights"] = fighter_df["n_draw"] + fighter_df["n_loss"] + fighter_df["n_win"]

# %%
fighter_df = fighter_df.dropna(subset=['sig_str_abs_pM', 'sig_str_def_pct', 'sig_str_land_pM', 'sig_str_land_pct','dob'])

# %%
fighter_df = fighter_df.drop((fighter_df.index[fighter_df["dob"] == '--']))

# %%
fighter_df = fighter_df.drop((fighter_df.index[fighter_df["sig_str_abs_pM"] == 0]))

# %%
fighter_df = fighter_df.reset_index(drop=True)

# %%
new = fighter_df["dob"].str.split(",")    
years = []

for i in new:
    year = i[1]
    years.append(year)
    
fighter_df['dob'] = years

# %%
fighter_df
# Out:
#         dob  height  n_draw  n_loss  n_win                name reach  \
# 0      1992   5' 8"       0       0      8        Hunter Azure   69"
# 1      1986   5' 6"       0       7     14         Jessica Eye   66"
# 2      1990   5' 8"       1       7      9          Rolando Dy   69"
# 3      1989   5' 9"       0       3      7      Gleidson Cutis    --
# 4      1984  5' 10"       0      12     17        Damien Brown   68"
# ...     ...     ...     ...     ...    ...                 ...   ...
# 2418   1989   5' 5"       0       1     11         Xiaonan Yan   63"
# 2419   1984   6' 3"       1       9     24  Alexander Yakovlev   74"
# 2420   1984   5' 6"       0      10     26          Rani Yahya   67"
# 2421   1979   5' 7"       1       5     16         Eddie Yagin    --
# 2422   1983   6' 1"       0       2      5         Jamie Yager    --
#
#       sig_str_abs_pM  sig_str_def_pct  sig_str_land_pM  sig_str_land_pct  \
# ...

# %%
fighter_df["dob"] = fighter_df["dob"].astype('int')
new = fighter_df["reach"].str.split('"')
reach = []
for i in new:
    x = i[0]
    reach.append(x)
fighter_df["reach"] = reach

fighter_df = fighter_df.replace({"stance": "--", "stance": "switch", "stance": "Sideways"}, "Orthodox")
fighter_df = fighter_df.replace({"stance": "Open Stance"}, "Southpaw")
fighter_df = fighter_df.replace({"stance": "Switch"}, "Orthodox")
values = {"stance": "Orthodox"}
fighter_df = fighter_df.fillna(value = values)

fighter_df = fighter_df.replace({"height": "--"}, "")
fighter_df = fighter_df.replace({"reach": "--"}, "")

# %%
fighter_df = fighter_df.drop_duplicates(subset=["name"])
fighter_df = fighter_df.reset_index(drop=True)

# %%
bout_detail_df = pd.read_json('bout_data.jl', lines =True)
bout_detail_df = bout_detail_df.dropna(how = 'any')
bout_detail_df
# Out:
#               fight_id                            fighter_id  \
# 0     d7cbe2f23d75afd1  [1291edf2d566a71a, 2c9d00968f818270]
# 1     f0418c2c989a5cde  [d3fa5c5955397532, 113df4fde64735c6]
# 2     fc16ccf0994c6e50  [b8a85389d115e35a, f97c5433c77522d3]
# 3     18e1b0df8da7010e  [9b7dfb3b7d99926a, 68d4a891e5cf2029]
# 4     57ff0eb2351979c4  [b4537562f88ac582, 294aa73dbf37d281]
# ...                ...                                   ...
# 5438  953c89aa931082e4  [36549928f90f1d36, 225def29ecfe0fc1]
# 5439  c163ed45c21c8548  [578ef12674df1e6a, 9b7dfb3b7d99926a]
# 5440  49b2a6a93d529981  [9c44f290f5726d95, b93c06d09d1c4ac0]
# 5441  fd3e8f61d8fda839  [792be9a24df82ed6, b1d19449397541dc]
# 5442  b2cdb4c34f37ad37  [d910665038efc639, e8b731feff72294b]
#
#                          fighter_name fighter_status      kd   n_pass   n_rev  \
# 0         [Julio Arce, Hakeem Dawodu]         [L, W]  [0, 0]   [2, 0]  [0, 1]
# ...

# %%
## Transformations required

# identify unneccessary columns i.e remove
# 'fighter_id', 'n_pass', 'n_rev', 'total_strike_def', 'td_abs', 'td_def', 'head_abs', 'head_att', 'head_def','head_abs',
#       'head_att', 'head_def', 'head_land', 'body_abs', 'body_att', 'body_def',
#      'body_land', 'leg_abs', 'leg_att', 'leg_def', 'leg_land',
#       'distance_abs', 'distance_att', 'distance_def', 'distance_land',
#       'clinch_abs', 'clinch_att', 'clinch_def', 'clinch_land', 'ground_abs',
#       'ground_att', 'ground_def', 'ground_land' 
# spearate doubled up columns and break into fighter_1, fighter_2 columns for each, create a new dataframe for this to preserve raw data
# after new dataframe is created, further manipulation is required after joining the dataframe with bout duration
# convert remaining striking columns into averages and percentages over the duration of the bout to align with fighter stats

# %%
bout_detail_df = bout_detail_df.drop(['fighter_id', 'n_pass', 'n_rev', 'td_abs', 'td_def', 'head_abs', 'head_att', 'head_def','head_abs',
       'head_att', 'head_def', 'head_land', 'body_abs', 'body_att', 'body_def',
      'body_land', 'leg_abs', 'leg_att', 'leg_def', 'leg_land',
       'distance_abs', 'distance_att', 'distance_def', 'distance_land',
       'clinch_abs', 'clinch_att', 'clinch_def', 'clinch_land', 'ground_abs',
      'ground_att', 'ground_def', 'ground_land'], axis = 1)

# %%
bout_detail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5417 entries, 0 to 5442
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fight_id        5417 non-null   object
#  1   fighter_name    5417 non-null   object
#  2   fighter_status  5417 non-null   object
#  3   kd              5417 non-null   object
#  4   n_sub           5417 non-null   object
#  5   sig_str_abs     5417 non-null   object
#  6   sig_str_att     5417 non-null   object
#  7   sig_str_def     5417 non-null   object
#  8   sig_str_land    5417 non-null   object
#  9   total_str_abs   5417 non-null   object
#  10  total_str_att   5417 non-null   object
#  11  total_str_def   5417 non-null   object
#  12  total_str_land  5417 non-null   object
#  13  td_att          5417 non-null   object
#  14  td_land         5417 non-null   object
# dtypes: object(15)
# memory usage: 677.1+ KB

# %%
fighter_1 = []
fighter_2 = []

fighter_1_kd = []
fighter_2_kd = []

fighter_1_nsub = []
fighter_2_nsub = []

fighter_1_sig_str_abs = []
fighter_2_sig_str_abs = []

fighter_1_sig_str_att =[]
fighter_2_sig_str_att =[]

fighter_1_sig_str_def = []
fighter_2_sig_str_def = []

fighter_1_sig_str_land = []
fighter_2_sig_str_land = []

fighter_1_tot_str_abs = []
fighter_2_tot_str_abs = []

fighter_1_tot_str_att = []
fighter_2_tot_str_att = []

fighter_1_tot_str_def = []
fighter_2_tot_str_def = []

fighter_1_tot_str_land = []
fighter_2_tot_str_land = []

fighter_1_td_att = []
fighter_2_td_att = []

fighter_1_td_land = []
fighter_2_td_land = []

# %%
new = bout_detail_df["fighter_name"]

for i in new:
    
    fighter_1_nm = i[0]
    fighter_2_nm = i[1]
    
    fighter_1.append(fighter_1_nm)
    fighter_2.append(fighter_2_nm)
    

    
for i in bout_detail_df["kd"].astype('string'):
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_kd.append(f1)
    fighter_2_kd.append(f2)
    
for i in bout_detail_df["n_sub"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])

    
    fighter_1_nsub.append(f1)
    fighter_2_nsub.append(f2)
    
for i in bout_detail_df["sig_str_abs"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_sig_str_abs.append(f1)
    fighter_2_sig_str_abs.append(f2)
    
for i in bout_detail_df["sig_str_att"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_sig_str_att.append(f1)
    fighter_2_sig_str_att.append(f2)
    
for i in bout_detail_df["sig_str_def"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_sig_str_def.append(f1)
    fighter_2_sig_str_def.append(f2)
    
for i in bout_detail_df["sig_str_land"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])

    
    fighter_1_sig_str_land.append(f1)
    fighter_2_sig_str_land.append(f2)
    
for i in bout_detail_df["total_str_abs"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_tot_str_abs.append(f1)
    fighter_2_tot_str_abs.append(f2)
    
for i in bout_detail_df["total_str_att"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_tot_str_att.append(f1)
    fighter_2_tot_str_att.append(f2)
    
for i in bout_detail_df["total_str_def"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])

    fighter_1_tot_str_def.append(f1)
    fighter_2_tot_str_def.append(f2)
    
for i in bout_detail_df["total_str_land"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])

    
    fighter_1_tot_str_land.append(f1)
    fighter_2_tot_str_land.append(f2)
    
for i in bout_detail_df["td_att"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_td_att.append(f1)
    fighter_2_td_att.append(f2)
    

    
for i in bout_detail_df["td_land"]:
    
    x = str(i)
    x = x.split(",")
    f1 = x[0]
    f1 = int((f1.split("["))[1])
    f2 = x[1]
    f2 = int((f2.split("]"))[0])
    
    fighter_1_td_land.append(f1)
    fighter_2_td_land.append(f2)

# %%
fight_id = bout_detail_df["fight_id"]
outcome = bout_detail_df["fighter_status"]

# %%
split_bout = pd.DataFrame({"fight_id": fight_id, 
                           "result": outcome, 
                           "fighter_1": fighter_1,
                           "fighter_1_kd": fighter_1_kd, 
                           "fighter_1_nsub": fighter_1_nsub,
                           "fighter_1_sig_abs": fighter_1_sig_str_abs,
                           "fighter_1_sig_att": fighter_1_sig_str_att,
                           "fighter_1_sig_def": fighter_1_sig_str_def,
                           "fighter_1_sig_land": fighter_1_sig_str_land,
                           "fighter_1_td_land": fighter_1_td_land, 
                           "fighter_1_td_att": fighter_1_td_att,
                           "fighter_2": fighter_2,
                           "fighter_2_kd": fighter_2_kd, 
                           "fighter_2_nsub": fighter_2_nsub,
                           "fighter_2_sig_abs": fighter_2_sig_str_abs,
                           "fighter_2_sig_att": fighter_2_sig_str_att,
                           "fighter_2_sig_def": fighter_2_sig_str_def,
                           "fighter_2_sig_land": fighter_2_sig_str_land,
                           "fighter_2_td_land": fighter_2_td_land, 
                           "fighter_2_td_att": fighter_2_td_att,
                          })

# %%
x = str(split_bout['result'][5441])
x
# Out:
# "['D', 'D']"

# %%
split_bout = split_bout.drop(split_bout.loc[split_bout['result'].astype('string')==x].index, inplace = False).reset_index(drop=True)

# %%
split_bout.tail()
# Out:
#               fight_id  result      fighter_1  fighter_1_kd  fighter_1_nsub  \
# 5373  ad878cdd4fa36a3a  [L, W]     Polo Reyes             0               0
# 5374  953c89aa931082e4  [W, L]  Jose Quinonez             1               0
# 5375  c163ed45c21c8548  [W, L]   Irene Aldana             0               0
# 5376  49b2a6a93d529981  [L, W]   Martin Bravo             0               0
# 5377  b2cdb4c34f37ad37  [W, L]  Carla Esparza             0               0
#
#       fighter_1_sig_abs  fighter_1_sig_att  fighter_1_sig_def  \
# 5373                 12                 10                  4
# 5374                 32                117                 83
# 5375                 68                333                182
# 5376                 49                199                 56
# 5377                 45                 80                 58
#
#       fighter_1_sig_land  fighter_1_td_land  fighter_1_td_att  \
# 5373                   6                  0                 0
# ...

# %%
outcome = []
outcome_binary = []

# 1 in the outcome column means fighter 1 is the victor

for i in split_bout["result"].astype('string'):
    
    if i == "['W', 'L']":
        outcome.append("Winner-Fighter 1")
        outcome_binary.append(1)
    else:
        outcome.append("Winner-Fighter 2")
        outcome_binary.append(0)
len(outcome)
len(outcome_binary)
# Out:
# 5378

# %%
split_bout["outcome"] = outcome
split_bout["outcome_binary"] = outcome_binary

# %%
joined_bout = split_bout.join(bout_df.set_index("fight_id"), how="inner", on="fight_id")
joined_bout["date"] = joined_bout["date"].astype("int")
joined_bout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4723 entries, 0 to 5377
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   fight_id                     4723 non-null   object
#  1   result                       4723 non-null   object
#  2   fighter_1                    4723 non-null   object
#  3   fighter_1_kd                 4723 non-null   int64
#  4   fighter_1_nsub               4723 non-null   int64
#  5   fighter_1_sig_abs            4723 non-null   int64
#  6   fighter_1_sig_att            4723 non-null   int64
#  7   fighter_1_sig_def            4723 non-null   int64
#  8   fighter_1_sig_land           4723 non-null   int64
#  9   fighter_1_td_land            4723 non-null   int64
#  10  fighter_1_td_att             4723 non-null   int64
#  11  fighter_2                    4723 non-null   object
#  12  fighter_2_kd                 4723 non-null   int64
# ...

# %%
joined_bout["fighter_1_sub_avg"] = joined_bout["fighter_1_nsub"]/joined_bout["fight_length_min"]
joined_bout["fighter_1_SLpM"] = joined_bout["fighter_1_sig_abs"]/joined_bout["fight_length_min"]
joined_bout["fighter_1_str_acc"] = joined_bout["fighter_1_sig_land"]/joined_bout["fighter_1_sig_att"]
joined_bout["fighter_1_SApM"] = joined_bout["fighter_1_sig_abs"]/joined_bout["fight_length_min"]
joined_bout["fighter_1_str_def"] = joined_bout["fighter_1_sig_def"]/joined_bout["fighter_2_sig_att"]
joined_bout["fighter_1_td_avg"] = joined_bout["fighter_1_td_land"]/joined_bout["fight_length_min"]
joined_bout["fighter_1_td_acc"] = joined_bout["fighter_1_td_land"]/joined_bout["fighter_1_td_att"]

joined_bout["fighter_2_sub_avg"] = joined_bout["fighter_2_nsub"]/joined_bout["fight_length_min"]
joined_bout["fighter_2_SLpM"] = joined_bout["fighter_2_sig_abs"]/joined_bout["fight_length_min"]
joined_bout["fighter_2_str_acc"] = joined_bout["fighter_2_sig_land"]/joined_bout["fighter_2_sig_att"]
joined_bout["fighter_2_SApM"] = joined_bout["fighter_2_sig_abs"]/joined_bout["fight_length_min"]
joined_bout["fighter_2_str_def"] = joined_bout["fighter_2_sig_def"]/joined_bout["fighter_1_sig_att"]
joined_bout["fighter_2_td_avg"] = joined_bout["fighter_2_td_land"]/joined_bout["fight_length_min"]
joined_bout["fighter_2_td_acc"] = joined_bout["fighter_2_td_land"]/joined_bout["fighter_2_td_att"]


joined_bout
# Out:
#               fight_id  result       fighter_1  fighter_1_kd  fighter_1_nsub  \
# 0     d7cbe2f23d75afd1  [L, W]      Julio Arce             0               0
# 1     f0418c2c989a5cde  [L, W]  Grigorii Popov             0               0
# 2     fc16ccf0994c6e50  [W, L]      Jack Shore             0               1
# 3     18e1b0df8da7010e  [L, W]    Vanessa Melo             0               0
# 4     57ff0eb2351979c4  [W, L]     Khalid Taha             1               1
# ...                ...     ...             ...           ...             ...
# 5373  ad878cdd4fa36a3a  [L, W]      Polo Reyes             0               0
# 5374  953c89aa931082e4  [W, L]   Jose Quinonez             1               0
# 5375  c163ed45c21c8548  [W, L]    Irene Aldana             0               0
# 5376  49b2a6a93d529981  [L, W]    Martin Bravo             0               0
# 5377  b2cdb4c34f37ad37  [W, L]   Carla Esparza             0               0
#
# ...

# %%
data_df = joined_bout[[
    "fighter_1_SLpM",
    "fighter_1_str_acc",
    "fighter_1_SApM",
    "fighter_1_str_def",
    "fighter_1_td_avg",
    "fighter_1_td_acc",
    "fighter_1_sub_avg",
    "fighter_2_SLpM",
    "fighter_2_str_acc",
    "fighter_2_SApM",
    "fighter_2_str_def",
    "fighter_2_td_avg",
    "fighter_2_td_acc",
    "fighter_2_sub_avg",
    "outcome",
    "outcome_binary"
]]

# %%
data_df
# Out:
#       fighter_1_SLpM  fighter_1_str_acc  fighter_1_SApM  fighter_1_str_def  \
# 0           3.666667           0.258065        3.666667           0.604317
# 1           2.000000           0.397727        2.000000           0.523810
# 2           0.493827           0.500000        0.493827           0.833333
# 3           5.266667           0.320000        5.266667           0.435714
# 4           1.666667           0.431818        1.666667           0.600000
# ...              ...                ...             ...                ...
# 5373        0.895522           0.600000        0.895522           0.250000
# 5374        2.133333           0.512821        2.133333           0.721739
# 5375        4.533333           0.375375        4.533333           0.728000
# 5376        3.634116           0.432161        3.634116           0.533333
# 5377        3.000000           0.550000        3.000000           0.563107
#
# ...

# %%
data_df = data_df.dropna(how="any", inplace=False).reset_index(drop=True)

# %%
fighter_df = fighter_df.reset_index(drop=True)

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
engine = create_engine('postgresql+psycopg2://postgres:cdw@localhost/ufc')
session = Session(engine)

# %%
joined_bout.to_sql('joined_fight', con=engine, if_exists='append',index=False)

# %%
fighter_df.to_sql('fighters', con=engine, if_exists='append', index=True)

# %%
data_df.to_sql('model_data', con=engine, if_exists='append', index = False)

# %%
## Data pre-processing for the model

# %%
X = data_df.drop(["outcome", "outcome_binary"], axis=1)
y = data_df["outcome"]
print(X.shape, y.shape)
# Out:
# (2087, 14) (2087,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()

label_encoder.fit(y_train)

encoded_y_train = label_encoder.transform(y_train)

encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)

y_test_categorical = to_categorical(encoded_y_test)

# %%
# Create Deep-Learning Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(units=100, activation='relu', input_dim=14))

#model.add(Dense(units=100, activation='relu'))

model.add(Dense(units=100, activation='relu'))

model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               1500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# ...
# Total params: 11,802
# Trainable params: 11,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 1565 samples
# Epoch 1/100
# 1565/1565 - 0s - loss: 0.5757 - accuracy: 0.6895
# Epoch 2/100
# 1565/1565 - 0s - loss: 0.4817 - accuracy: 0.7687
# Epoch 3/100
# 1565/1565 - 0s - loss: 0.4479 - accuracy: 0.7955
# Epoch 4/100
# 1565/1565 - 0s - loss: 0.4284 - accuracy: 0.8096
# Epoch 5/100
# 1565/1565 - 0s - loss: 0.4259 - accuracy: 0.8089
# Epoch 6/100
# 1565/1565 - 0s - loss: 0.4226 - accuracy: 0.8192
# Epoch 7/100
# 1565/1565 - 0s - loss: 0.4178 - accuracy: 0.8160
# Epoch 8/100
# 1565/1565 - 0s - loss: 0.4164 - accuracy: 0.8115
# Epoch 9/100
# 1565/1565 - 0s - loss: 0.4121 - accuracy: 0.8204
# Epoch 10/100
# 1565/1565 - 0s - loss: 0.4071 - accuracy: 0.8173
# Epoch 11/100
# 1565/1565 - 0s - loss: 0.4127 - accuracy: 0.8153
# Epoch 12/100
# 1565/1565 - 0s - loss: 0.4075 - accuracy: 0.8217
# Epoch 13/100
# 1565/1565 - 0s - loss: 0.4136 - accuracy: 0.8153
# Epoch 14/100
# 1565/1565 - 0s - loss: 0.4025 - accuracy: 0.8230
# Epoch 15/100
# ...

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)

print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 522/522 - 0s - loss: 0.4372 - accuracy: 0.8257
# Normal Neural Network - Loss: 0.43721645876365606, Accuracy: 0.8256704807281494

# %%
encoded_predictions = model.predict_classes([X_test_scaled[:10]])

prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['Winner-Fighter 1' 'Winner-Fighter 1' 'Winner-Fighter 1'
#  'Winner-Fighter 1' 'Winner-Fighter 1' 'Winner-Fighter 1'
#  'Winner-Fighter 1' 'Winner-Fighter 1' 'Winner-Fighter 2'
#  'Winner-Fighter 1']
# Actual Labels: ['Winner-Fighter 2', 'Winner-Fighter 1', 'Winner-Fighter 1', 'Winner-Fighter 2', 'Winner-Fighter 1', 'Winner-Fighter 1', 'Winner-Fighter 1', 'Winner-Fighter 1', 'Winner-Fighter 2', 'Winner-Fighter 1']

# %%
model.save("ufc_model_trained.h5")

# %%
from tensorflow.keras.models import load_model
ufc_model = load_model("ufc_model_trained.h5")

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)

print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 522/522 - 0s - loss: 0.6744 - accuracy: 0.6533
# Normal Neural Network - Loss: 0.6744398655105824, Accuracy: 0.6532567143440247

# %%
# create dataframe which holds every fighter pair and match up with the data required for the model
# run that data through the model predictor to have an ooutcome for every fighter pair

predict_fighter_df = fighter_df.drop(labels = ["dob", "height", "n_win",
                                               "n_loss", "n_draw", "reach", 
                                               "stance", "td_def_pct", "total_fights"], axis = 1)

# %%
predict_fighter_df
# Out:
#                     name  sig_str_abs_pM  sig_str_def_pct  sig_str_land_pM  \
# 0           Hunter Azure            1.57             0.56             4.00
# 1            Jessica Eye            3.36             0.60             3.51
# 2             Rolando Dy            4.47             0.52             3.04
# 3         Gleidson Cutis            8.28             0.59             2.99
# 4           Damien Brown            4.86             0.50             3.66
# ...                  ...             ...              ...              ...
# 2417         Xiaonan Yan            4.22             0.64             6.85
# 2418  Alexander Yakovlev            2.44             0.58             1.79
# 2419          Rani Yahya            1.61             0.52             1.59
# 2420         Eddie Yagin            5.77             0.42             3.13
# 2421         Jamie Yager            2.55             0.63             3.08
#
#       sig_str_land_pct  sub_avg  td_avg  td_land_pct    weight
# ...

# %%
fighter_pairs = []
fighter_1 = []
fighter_2 = []

for row in predict_fighter_df["name"]:
    for name in predict_fighter_df["name"]:
    
        fighter_pair = row + "/" + name
        f_1 = row
        f_2 = name
        fighter_pairs.append(fighter_pair)
        fighter_1.append(f_1)
        fighter_2.append(f_2)

# %%
weight_class = []


for row in predict_fighter_df["weight"]:
    for name in predict_fighter_df["weight"]:
    
        weight = row + "/" + name
        weight_class.append(weight)

# %%
f_1_SLpM = []
f_1_str_acc = []
f_1_SApM = []
f_1_str_def = []
f_1_td_acc = []
f_1_td_avg = []
f_1_sub_avg = []
f_2_SLpM = []
f_2_str_acc = []
f_2_SApM = []
f_2_str_def = []
f_2_td_acc = []
f_2_td_avg = []
f_2_sub_avg = []


for row in predict_fighter_df["sig_str_land_pM"]:
    for name in predict_fighter_df["sig_str_land_pM"]:
    
        f_1 = row
        f_2 = name
        f_1_SLpM.append(row)
        f_2_SLpM.append(name)
    
            
for row in predict_fighter_df["sig_str_land_pct"]:
    for name in predict_fighter_df["sig_str_land_pct"]:
    
        f_1 = row
        f_2 = name
        f_1_str_acc.append(row)
        f_2_str_acc.append(name)
        
        
for row in predict_fighter_df["sig_str_abs_pM"]:
    for name in predict_fighter_df["sig_str_abs_pM"]:
    
        f_1 = row
        f_2 = name
        f_1_SApM.append(row)
        f_2_SApM.append(name)
        
        
for row in predict_fighter_df["sig_str_def_pct"]:
    for name in predict_fighter_df["sig_str_def_pct"]:
    
        f_1 = row
        f_2 = name
        f_1_str_def.append(row)
        f_2_str_def.append(name)
        
        
for row in predict_fighter_df["td_avg"]:
    for name in predict_fighter_df["td_avg"]:
    
        f_1 = row
        f_2 = name
        f_1_td_avg.append(row)
        f_2_td_avg.append(name)
        
        
for row in predict_fighter_df["td_land_pct"]:
    for name in predict_fighter_df["td_land_pct"]:
    
        f_1 = row
        f_2 = name
        f_1_td_acc.append(row)
        f_2_td_acc.append(name)
        
        
for row in predict_fighter_df["sub_avg"]:
    for name in predict_fighter_df["sub_avg"]:
    
        f_1 = row
        f_2 = name
        f_1_sub_avg.append(row)
        f_2_sub_avg.append(name)

# %%
predict_data_df = pd.DataFrame({
                           "fighter_pair": fighter_pairs,
                           "fighter_1": fighter_1, 
                           "fighter_1_SLpM": f_1_SLpM,
                           "fighter_1_str_acc": f_1_str_acc,
                           "fighter_1_SApM": f_1_SApM,
                           "fighter_1_str_def": f_1_str_def,
                           "fighter_1_td_avg": f_1_td_avg,
                           "fighter_1_td_acc": f_1_td_acc, 
                           "fighter_1_sub_avg": f_1_sub_avg,
                           "fighter_2": fighter_2,
                           "fighter_2_SLpM": f_2_SLpM, 
                           "fighter_2_str_acc": f_2_str_acc,
                           "fighter_2_SApM": f_2_SApM,
                           "fighter_2_str_def": f_2_str_def,
                           "fighter_2_td_avg": f_2_td_avg,
                           "fighter_2_td_acc": f_2_td_acc,
                           "fighter_2_sub_avg": f_2_sub_avg, 
                           "weight_class": weight_class
                          })

# %%
predict_data_df
# Out:
#                            fighter_pair     fighter_1  fighter_1_SLpM  \
# 0             Hunter Azure/Hunter Azure  Hunter Azure            4.00
# 1              Hunter Azure/Jessica Eye  Hunter Azure            4.00
# 2               Hunter Azure/Rolando Dy  Hunter Azure            4.00
# 3           Hunter Azure/Gleidson Cutis  Hunter Azure            4.00
# 4             Hunter Azure/Damien Brown  Hunter Azure            4.00
# ...                                 ...           ...             ...
# 5866079         Jamie Yager/Xiaonan Yan   Jamie Yager            3.08
# 5866080  Jamie Yager/Alexander Yakovlev   Jamie Yager            3.08
# 5866081          Jamie Yager/Rani Yahya   Jamie Yager            3.08
# 5866082         Jamie Yager/Eddie Yagin   Jamie Yager            3.08
# 5866083         Jamie Yager/Jamie Yager   Jamie Yager            3.08
#
#          fighter_1_str_acc  fighter_1_SApM  fighter_1_str_def  \
# 0                     0.50            1.57               0.56
# ...

# %%
predict_data_clean = predict_data_df.drop(labels = ["fighter_pair", "fighter_1", "fighter_2", "weight_class"], axis = 1)
predict_data_clean
# Out:
#          fighter_1_SLpM  fighter_1_str_acc  fighter_1_SApM  fighter_1_str_def  \
# 0                  4.00               0.50            1.57               0.56
# 1                  4.00               0.50            1.57               0.56
# 2                  4.00               0.50            1.57               0.56
# 3                  4.00               0.50            1.57               0.56
# 4                  4.00               0.50            1.57               0.56
# ...                 ...                ...             ...                ...
# 5866079            3.08               0.39            2.55               0.63
# 5866080            3.08               0.39            2.55               0.63
# 5866081            3.08               0.39            2.55               0.63
# 5866082            3.08               0.39            2.55               0.63
# 5866083            3.08               0.39            2.55               0.63
#
# ...

# %%
predict_data_scaled = X_scaler.transform(predict_data_clean)

# %%
encoded_predictions = model.predict_classes([predict_data_scaled])

prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
predict_data_df["winner"] = prediction_labels
